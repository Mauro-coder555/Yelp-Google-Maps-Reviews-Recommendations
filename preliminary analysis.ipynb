# %%
import pandas as pd
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_12608\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_json('Data/review.json', lines=True)

# %%
df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# ...

# %%
df[df.duplicated(subset=['user_id', 'business_id', 'stars', 'text', 'date'], keep=False)]
# Out:
#                       review_id                 user_id  \
# 495992   f-eseFSV4xnvMDuHmRxWOQ  FHIZVv4yXhSAULPkxqsHxQ
# 645298   FmEWJou0hHUiEGCMmThz5Q  FHIZVv4yXhSAULPkxqsHxQ
# 688326   d-2yAAWXkT9iMUcIly1zVQ  FHIZVv4yXhSAULPkxqsHxQ
# 1255202  gZU6syBqLk210QhnwWbSyw  6d4TXsdOZAsw8_h1r730uA
# 1279906  6FJ-pUVQsMFHhW4RJltm6w  6d4TXsdOZAsw8_h1r730uA
# 1391489  uN7sRdsxIJgmD5REegSpBA  6d4TXsdOZAsw8_h1r730uA
# 2661984  lzBHkMZayoGSpIPDOIIEug  3B5wkOgsrjBjXRpGdrmTSA
# 2736490  CB9ScDB-MYTWVyd1E9dSgw  wAph_egpAXr9ic-A2vnINQ
# 2753763  qcYQmZuP4ywuYmYfcyAuYQ  wAph_egpAXr9ic-A2vnINQ
# 2774499  QacdXke_oZAD662oeFyUxg  3B5wkOgsrjBjXRpGdrmTSA
# 3113588  1lyNZzBeJXrAMxvZU_-7Aw  T870ZkavUI1rqaO_FrJFiw
# 3116545  qkbLeGVNwxY9-5iMDcwZGw  T870ZkavUI1rqaO_FrJFiw
# 5474011  XjlaQ5ImGg1uL2XelQA2xw  xZ0ioQJ0Jyo_Uc0FzmyFQQ
# 5521113  8JcvaBpFPAe7lIVSazi0hQ  xZ0ioQJ0Jyo_Uc0FzmyFQQ
# 6369843  dVPOp7YLlGaxjT_70GdAQA  HQbMlz5dUFb5CMKAT6p3qg
# 6531617  9cYYew0rsqN5PeFV5kbOrQ  HQbMlz5dUFb5CMKAT6p3qg
#
# ...

# %%
df_bus = pd.read_pickle('Data/business.pkl')

# %%
df_bus.isna().sum()
# Out:
# business_id          0
# name                 0
# address              0
# city                 0
# state                3
# postal_code          0
# latitude             0
# longitude            0
# stars                0
# review_count         0
# is_open              0
# attributes       13744
# categories         103
# hours            23223
# business_id     150341
# name            150341
# address         150341
# city            150341
# state           150341
# postal_code     150341
# latitude        150341
# longitude       150341
# stars           150341
# review_count    150341
# is_open         150341
# attributes      150341
# categories      150341
# hours           150341
# dtype: int64

# %%
df_bus = df_bus.iloc[:, :14]

# %%
df_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
# dtypes: object(14)
# memory usage: 17.2+ MB

# %%
df_bus['state'].unique()
# Out:
# array([nan, 'CA', 'MO', 'AZ', 'PA', 'TN', 'FL', 'IN', 'LA', 'AB', 'NV',
#        'ID', 'DE', 'IL', 'NJ', 'NC', 'CO', 'WA', 'HI', 'UT', 'TX', 'MT',
#        'MI', 'SD', 'XMS', 'MA', 'VI', 'VT'], dtype=object)

# %%
df_bus['state'].value_counts()
# Out:
# state
# PA     34039
# FL     26329
# TN     12056
# IN     11246
# MO     10913
# LA      9924
# AZ      9912
# NJ      8536
# NV      7715
# AB      5573
# CA      5203
# ID      4467
# DE      2265
# IL      2144
# TX         4
# CO         3
# WA         2
# HI         2
# MA         2
# NC         1
# UT         1
# MT         1
# MI         1
# SD         1
# XMS        1
# VI         1
# VT         1
# Name: count, dtype: int64

# %%
df_bus = df_bus[(df_bus['state'] == 'FL') | (df_bus['state'] == 'NV') | (df_bus['state'] == 'CA')]

# %%
df_bus[df_bus.duplicated(subset=['business_id'])]
# Out:
# Empty DataFrame
# Columns: [business_id, name, address, city, state, postal_code, latitude, longitude, stars, review_count, is_open, attributes, categories, hours]
# Index: []

# %%
df = df[df['business_id'].isin(df_bus.business_id)]

# %%
df.drop(columns=['useful', 'funny', 'cool'])
# Out:
#                       review_id                 user_id  \
# 7        _ZeMknuYdlQcUqng_Im3yg  yfFzsLmaWF2d4Sr0UNbBgg
# 9        pUycOfUwM8vqX7KjRRhUEA  59MxRhNVhU9MYndMkz0wtw
# 14       UBp0zWyH60Hmw6Fsasei7w  4Uh27DgGzsp6PqrH913giQ
# 19       Xs8Z8lmKkosqW5mw_sVAoA  IQsF3Rc6IgCzjVV9DE8KXg
# 22       J-4NdnDZ0pUQaUEEwDI9KQ  vrKkXsozqqecF3CW4cGaVQ
# ...                         ...                     ...
# 6990269  cACxcUY_AIsQKkpDRXuqnw  MCzlzlOw7IGbRAKVjJBPtg
# 6990272  wD5ZWao_vjyT2h4xmGam8Q  7L7GL5Pi2cf8mbm2Dpw4zw
# 6990273  zHZ-A1qyKDEgyZMDaD--wg  _XVdmFWSgTN6YlojUxixTA
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  \
# 7        LHSTtnW3YHCeUkRDGyJOyw      5
# 9        gebiRewfieSdtt17PTW6Zg      3
# 14       otQS34_MymijPTdNBoBdCw      4
# 19       eFvzHawVJofxSnD7TgbZtg      5
# 22       rjuWz_AD3WfXJc03AhIO_w      5
# ...                         ...    ...
# ...

# %%
df.to_csv('')
